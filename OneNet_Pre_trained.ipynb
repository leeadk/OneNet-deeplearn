# %% [markdown]
# <a href="https://colab.research.google.com/github/leeadk/OneNet-deeplearn/blob/main/OneNet_Pre_trained.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/PeizeSun/OneNet.git
# Out:
# Cloning into 'OneNet'...
# remote: Enumerating objects: 602, done.
# remote: Counting objects: 100% (602/602), done.
# remote: Compressing objects: 100% (499/499), done.
# remote: Total 602 (delta 135), reused 523 (delta 93), pack-reused 0
# Receiving objects: 100% (602/602), 1.50 MiB | 27.44 MiB/s, done.
# Resolving deltas: 100% (135/135), done.

# %%
cd OneNet
# Out:
# /content/OneNet

# %% [markdown]
# #  installing torchvison

# %%
pip install torch==1.7.1+cu101 torchvision==0.8.2+cu101 torchaudio===0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 735.4MB 25kB/s
# ...
#      |████████████████████████████████| 12.8MB 20.6MB/s
# ...
#      |████████████████████████████████| 7.6MB 28.0MB/s
# ...
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.7.1+cu101 which is incompatible.
# ...
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
#   Found existing installation: torchvision 0.9.1+cu101
#     Uninstalling torchvision-0.9.1+cu101:
#       Successfully uninstalled torchvision-0.9.1+cu101
# ...

# %% [markdown]
# # restart runtime after installing

# %%
# !pip install pyyaml==5.1 pycocotools>=2.0.1

# %%
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
# Out:
# 1.7.1+cu101 True

# %% [markdown]
# # install onenet

# %%
# !python setup.py build develop
# Out:
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/detectron2
# copying detectron2/__init__.py -> build/lib.linux-x86_64-3.7/detectron2
# creating build/lib.linux-x86_64-3.7/detectron2/export
# copying detectron2/export/torchscript.py -> build/lib.linux-x86_64-3.7/detectron2/export
# copying detectron2/export/api.py -> build/lib.linux-x86_64-3.7/detectron2/export
# copying detectron2/export/caffe2_modeling.py -> build/lib.linux-x86_64-3.7/detectron2/export
# copying detectron2/export/c10.py -> build/lib.linux-x86_64-3.7/detectron2/export
# copying detectron2/export/__init__.py -> build/lib.linux-x86_64-3.7/detectron2/export
# copying detectron2/export/torchscript_patch.py -> build/lib.linux-x86_64-3.7/detectron2/export
# copying detectron2/export/shared.py -> build/lib.linux-x86_64-3.7/detectron2/export
# copying detectron2/export/caffe2_inference.py -> build/lib.linux-x86_64-3.7/detectron2/export
# ...

# %% [markdown]
# # Connecting files of COCO dataset

# %%
# !mkdir -p datasets/coco/annotations/
# !cp /content/drive/MyDrive/instances_val2017.json /content/OneNet/datasets/coco/annotations
# !ln -s /content/drive/MyDrive/val2017 /content/OneNet/datasets/coco/

# %% [markdown]
# # Evaluate

# %%
# !python projects/OneNet/train_net.py --num-gpus 1 \
    --config-file projects/OneNet/configs/onenet.res18.dcn.yaml \
    --eval-only MODEL.WEIGHTS /content/drive/MyDrive/onenet_r18dcn.pth
# Out:
# Command Line Args: Namespace(config_file='projects/OneNet/configs/onenet.res18.dcn.yaml', dist_url='tcp://127.0.0.1:49152', eval_only=True, machine_rank=0, num_gpus=1, num_machines=1, opts=['MODEL.WEIGHTS', '/content/drive/MyDrive/onenet_r18dcn.pth'], resume=False)
# [06/12 17:07:11 detectron2]: Rank of current process: 0. World size: 1
# [06/12 17:07:11 detectron2]: Environment info:
# ----------------------  ---------------------------------------------------------------
# sys.platform            linux
# Python                  3.7.10 (default, May  3 2021, 02:48:31) [GCC 7.5.0]
# numpy                   1.19.5
# detectron2              0.3 @/content/OneNet/detectron2
# Compiler                GCC 7.5
# CUDA compiler           CUDA 11.0
# detectron2 arch flags   7.5
# DETECTRON2_ENV_MODULE   <not set>
# PyTorch                 1.7.1+cu101 @/usr/local/lib/python3.7/dist-packages/torch
# PyTorch debug build     False
# GPU available           True
# ...

# %% [markdown]
# # Visualize
# install opencv additinoally for visualize

# %%
# !python demo/demo.py\
    --config-file projects/OneNet/configs/onenet.res18.dcn.yaml \
    --input /content/drive/MyDrive/images.jpg --output /content/ --confidence-threshold 0.4 \
    --opts MODEL.WEIGHTS /content/drive/MyDrive/onenet_r18dcn.pth
# Out:
# [06/12 17:13:45 detectron2]: Arguments: Namespace(confidence_threshold=0.4, config_file='projects/OneNet/configs/onenet.res18.dcn.yaml', input=['/content/drive/MyDrive/images.jpg'], opts=['MODEL.WEIGHTS', '/content/drive/MyDrive/onenet_r18dcn.pth'], output='/content/', video_input=None, webcam=False)
# [06/12 17:13:48 fvcore.common.checkpoint]: [Checkpointer] Loading from /content/drive/MyDrive/onenet_r18dcn.pth ...
#   0% 0/1 [00:00<?, ?it/s][06/12 17:13:53 detectron2]: /content/drive/MyDrive/images.jpg: detected 13 instances in 0.19s
# 100% 1/1 [00:00<00:00,  1.24it/s]
